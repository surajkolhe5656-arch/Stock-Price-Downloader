# %% [markdown]
# 1. Import libraries

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# 2. Define stocks and fetch data

# %%
stocks = ["HDFCBANK.NS", "RELIANCE.NS", "TCS.NS", "INFY.NS", "ICICIBANK.NS"]
data = yf.download(stocks, start="2020-01-01", end="2025-01-01")["Close"]
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5744\1087693642.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stocks, start="2020-01-01", end="2025-01-01")["Close"]
# [*********************100%***********************]  5 of 5 completed

# %% [markdown]
# 3. Compute daily returns

# %%
returns = data.pct_change().dropna()

# %% [markdown]
# 4. Create the correlation matrix

# %%
corr_matrix = returns.corr()
print(corr_matrix)
# Out:
# Ticker        HDFCBANK.NS  ICICIBANK.NS   INFY.NS  RELIANCE.NS    TCS.NS
# Ticker
# HDFCBANK.NS      1.000000      0.639451  0.357704     0.441789  0.313980
# ICICIBANK.NS     0.639451      1.000000  0.377474     0.438453  0.335536
# INFY.NS          0.357704      0.377474  1.000000     0.361079  0.707904
# RELIANCE.NS      0.441789      0.438453  0.361079     1.000000  0.386559
# TCS.NS           0.313980      0.335536  0.707904     0.386559  1.000000

# %% [markdown]
# 5. Plot the heatmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Stock Correlation Heatmap")
plt.show()
